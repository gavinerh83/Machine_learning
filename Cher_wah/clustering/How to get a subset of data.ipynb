# %%
import numpy as np
import pandas as pd

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer Id', 'Age', 'Edu', 'Years Employed', 'Income',
#        'Card Debt', 'Other Debt', 'Defaulted', 'DebtIncomeRatio'],
#       dtype='object')

# %%
df = pd.read_csv("cust_seg.csv")
df.drop(['Unnamed: 0', 'Customer Id'], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#    Age  Edu  Years Employed  Income  Card Debt  Other Debt  Defaulted  \
# 0   41    2               6      19      0.124       1.073        0.0
# 1   47    1              26     100      4.582       8.218        0.0
#
#    DebtIncomeRatio
# 0              6.3
# 1             12.8

# %%
df.loc[list(range(22,30)),'Age']
# Out:
# 22    28
# 23    45
# 24    37
# 25    43
# 26    24
# 27    37
# 28    38
# 29    34
# Name: Age, dtype: int64

# %%
df[df['Age'].isin([22,30])]
# Out:
#      Age  Edu  Years Employed  Income  Card Debt  Other Debt  Defaulted  \
# 38    22    1               1      18      0.270       0.522        0.0
# 46    22    1               4      14      0.225       2.225        0.0
# 47    30    1               4      21      0.229       0.506        NaN
# 70    30    3               8      61      0.550       1.158        0.0
# 72    30    2              12      98      2.935       4.121        0.0
# 81    30    3               0      65      3.900      15.405        1.0
# 86    22    4               0      25      1.491       1.559        NaN
# 99    22    3               0      20      0.219       0.721        0.0
# 100   30    1               7      33      1.165       7.217        1.0
# 112   30    1              10      39      2.056       1.649        0.0
# 116   30    1               4      18      0.227       1.699        0.0
# 143   30    1               8      23      0.762       1.998        0.0
# ...
